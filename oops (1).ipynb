# %% [markdown]
#  Q 1.What is Object-Oriented Programming (OOP)?
# - It is a programming style where you organize your code around objects rather than just functions and logic.

# %% [markdown]
# Q 2.What is a class in OOP?
# - A class is like a blueprint or template to create objects.

# %% [markdown]
# Q 3.What is an object in OOP?
#
# -  An object is a real instance created from a class (blueprint).
#
#   It contains:
#
# Data (called attributes)
#
# Behavior (called methods)

# %% [markdown]
# Q 4.What is the difference between abstraction and encapsulation
# -

# %% [markdown]
# - 1️⃣ Abstraction
# Shows only the essential features.
#
# Hides the complex inner working.
#
# Example:
# You drive a car using the steering wheel and pedals.
# You don’t need to know how the engine or brake system works. That’s abstraction.
#
# 2️⃣ Encapsulation
# Wraps the data and code together.
#
# Protects the data from direct access.
#
# Example:
# Your bank account balance is not directly accessible.
# You access it via methods like get_balance() — this is encapsulation.

# %% [markdown]
# Q 5. What are dunder methods in Python.?
# - Dunder means "Double UNDERSCORE" (i.e., methods with __ before and after their name).
#
# These are also called:
#
# - Magic methods
#
# - pecial methods
#
# They allow us to customize the behavior of Python's built-in operations like printing, adding, comparing, etc.

# %% [markdown]
# Q 6. Explain the concept of inheritance in OOP
# - Inheritance means one class (child) can inherit properties and methods from another class (parent).
#
# - It allows you to reuse code and create a hierarchy between classes.

# %% [markdown]
# Q 7.What is polymorphism in OOP
# - olymorphism means:
# ➡️ "One name, many forms."
#
# In OOP, polymorphism allows the same method name to behave differently based on the object that calls it.

# %% [markdown]
# Q 8.How is encapsulation achieved in Python+
# - Encapsulation is achieved in Python by:
#
# Making variables private (using double underscore __)
#
# Providing getter and setter methods to access or update the data.

# %% [markdown]
# Q 9.What is a constructor in Python+
# - A constructor in Python is a special method that runs automatically when you create an object of a class.
# Its main job is to initialize the object with default or given values

# %% [markdown]
# Q 10. What are class and static methods in Python
#
# 1) Class Method
#
# It works with the class itself (not the object).
#
# It can access and modify class-level data (but not instance-level).
#
# Marked with the @classmethod decorator.
#
# Takes cls as the first argument (instead of self).
#
# 2) Static Method
#
# It doesn’t care about object or class — works independently.
#
# Just a function inside a class for better organization.
#
# Marked with the @staticmethod decorator.
#
# Doesn’t take self or cls.

# %% [markdown]
# Q 11.What is method overloading in Python+
# - Method Overloading occurs when multiple methods with the same name exist in a class but different parameters. The correct method is selected based on the number or type of arguments passed.

# %% [markdown]
# Q 12 . What is method overriding in OOP
#
# Method Overriding occurs when a subclass provides a specific implementation of a method that is already defined in its parent class. The method in the subclass replaces or overrides the method in the parent class, allowing the subclass to modify or extend its behavior.
# -

# %% [markdown]
# Q 13. What is a property decorator in Python
# - In Python, a property decorator is used to define getter, setter, and deleter methods for a class attribute, allowing you to access and modify the attribute in a controlled manner.

# %% [markdown]
# Q 14.Why is polymorphism important in OOP
# - Polymorphism is a fundamental concept in Object-Oriented Programming (OOP), and it plays a vital role in designing flexible, reusable, and maintainable code.

# %% [markdown]
# Q 15. What is an abstract class in Python
# - An abstract class is a class that cannot be instantiated on its own and serves as a blueprint for other classes. It is used to define a common interface and behavior that must be implemented by any subclass.

# %% [markdown]
# Q 16.What are the advantages of OOP
# - Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around data, or objects, rather than functions and logic. It brings several advantages that enhance code readability, maintainability, modularity, and reusability.

# %% [markdown]
# Q 17. What is the difference between a class variable and an instance variable
# - A class variable is a variable that is shared by all instances of a class. It is defined within the class but outside any instance methods, and it is not tied to any particular instance of the class. Class variables are typically used to store values that are common to all instances of a class.
# - An instance variable is a variable that is specific to each instance of a class. Each object (instance) has its own copy of the instance variable, and changes to one instance's variables do not affect the others. Instance variables are defined inside the __init__ method (or other instance methods) using the self keyword.

# %% [markdown]
# Q 18.What is multiple inheritance in Python
# - Multiple inheritance is a feature in Python that allows a class to inherit from more than one parent class. This means that a single class can have multiple parent classes, and it can inherit attributes and methods from all of them. This is different from single inheritance, where a class can only inherit from one parent class.

# %% [markdown]
# Q 19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# - The __str__ method is used to define the "informal" or user-friendly string representation of an object. It's what gets displayed when we print an object or convert it to a string using the str() function.
#
# - Purpose: It provides a human-readable, more understandable string representation of the object, meant for display to the end user.
#
# - The __repr__ method is used to define the formal or developer-friendly string representation of an object. The goal of __repr__ is to return a string that, when passed to the eval() function (or evaluated by a developer), would ideally create an object with the same state as the original object. This string should be precise and unambiguous.
#
# - Purpose: It provides a detailed, unambiguous string representation that is useful for debugging and development purposes.

# %% [markdown]
# Q 20.What is the significance of the ‘super()’ function in Python
# - Calling Parent Class Methods:
#
# super() allows you to call methods from the parent class (superclass), which is especially useful when overriding methods in a subclass.
#
# This ensures that you don’t have to explicitly refer to the parent class name when calling methods from it.
#
# - Avoiding Explicit Class Names:
#
# One of the main benefits of super() is that it avoids the need to explicitly use the name of the parent class, which enhances the maintainability and flexibility of your code. If you ever change the name of the parent class, you don’t have to modify the child classes.
#
# - Simplifying Multiple Inheritance:
#
# In multiple inheritance scenarios, super() is particularly helpful as it allows you to ensure that the correct method is called from the appropriate class, following the Method Resolution Order (MRO).
#
# - Supporting the __init__ Method:
#
# super() is commonly used in the constructor __init__ to ensure that the parent class's initialization is correctly called when an object is instantiated. This is especially important in cases of multiple inheritance, where multiple base class constructors need to be executed.
# - Accessing the Next Class in the MRO:
#
# The super() function automatically follows the Method Resolution Order (MRO) to determine which method to call from the parent class. This helps in cases of complex inheritance chains, such as with multiple inheritance, by following the class hierarchy.

# %% [markdown]
# Q 21.What is the significance of the __del__ method in Python
# - Purpose:
#
# The primary purpose of the __del__ method is to define cleanup operations that should be executed when an object is about to be destroyed.
#
# These operations might involve closing files, releasing database connections, deallocating memory, or freeing other external resources.
#
# - Called When Object is Destroyed:
#
# The __del__ method is automatically called when the reference count of an object reaches zero (i.e., when no more references to the object exist).
#
# In Python, the garbage collector is responsible for deallocating memory and removing objects when they are no longer needed.
#
# - Garbage Collection:
#
# Python uses automatic memory management through garbage collection, so you typically do not need to explicitly free memory. The __del__ method can be used for resource deallocation instead of memory management.
#
# It is important to note that you cannot predict exactly when the __del__ method will be called because it depends on the garbage collection mechanism.
#
# - Limited Use:
#
# The __del__ method is not commonly used in Python programs because Python's garbage collector typically handles memory management and resource cleanup automatically.
#
# However, it can still be useful when dealing with external resources like file handles, network sockets, or databases, where timely cleanup is required.
#
# - Potential Pitfalls:
#
# Circular References: If an object is involved in a circular reference, Python’s garbage collector might not immediately destroy it, which could delay the execution of the __del__ method.
#
# Exceptions in __del__: If an exception is raised inside the __del__ method, Python ignores it and does not propagate it. This means that any error that occurs in __del__ will not be reported.

# %% [markdown]
# Q 22,What is the difference between @staticmethod and @classmethod in Python
# - 1. @staticmethod:
# Definition: A static method does not depend on the instance of the class (i.e., it does not require self), and it does not have access to class-level data or methods unless explicitly passed. Static methods are used for utility functions that can work independently of the class and its instance.
# - 2. @classmethod:
# Definition: A class method is bound to the class, not the instance, and it has access to the class-level data and methods. It takes the class itself as its first parameter (cls), which allows it to modify class-level attributes or call other class methods.

# %% [markdown]
# Q 23.How does polymorphism work in Python with inheritance+
#
# Method Overriding: In Python, polymorphism is typically achieved through method overriding, where a subclass provides a specific implementation of a method that is already defined in its superclass. The subclass method is called instead of the superclass method, allowing for different behavior.
#
# Dynamic Typing: Python’s dynamic typing allows you to call methods on objects without knowing their exact type at compile time. This contributes to polymorphism, as Python determines which method to call at runtime based on the object's type.
#
# Duck Typing: Python follows the principle of duck typing: "If it looks like a duck and quacks like a duck, it’s a duck." This means that polymorphism works in Python as long as an object has the required methods or properties, regardless of whether it is from the same class or a different class.

# %% [markdown]
# Q 24.What is method chaining in Python OOP
# - Method chaining is a programming technique where multiple methods are called on the same object in a single statement, with each method returning the object itself (or another object). This allows for the methods to be "chained" together, making the code more concise and easier to read.

# %% [markdown]
# Q 25.What is the purpose of the __call__ method in Python?
# - In Python, the __call__ method is a special or "dunder" (double underscore) method that allows an instance of a class to be called like a function. When you define this method in a class, you can make objects of that class callable, meaning you can "call" the object as if it were a function.

# %%
##################################################################################################

# %% [markdown]
# Practical Questions

# %% [markdown]
# Q 1.1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create an object of Animal
animal = Animal()
animal.speak()  # Output: The animal makes a sound

# Create an object of Dog
dog = Dog()
dog.speak()  # Output: Bark!
# Out:
# The animal makes a sound
# Bark!

# %% [markdown]
# Q 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

# Abstract class Shape
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)  # Area of a circle: π * r^2

# Derived class Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width  # Area of a rectangle: length * width

# Create objects and calculate areas
circle = Circle(5)  # Circle with radius 5
print(f"Area of Circle: {circle.area()}")

rectangle = Rectangle(4, 6)  # Rectangle with length 4 and width 6
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24

# %% [markdown]
# Q 3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
# Base class Vehicle
class Vehicle:
    def __init__(self, type_of_vehicle):
        self.type = type_of_vehicle

    def show_type(self):
        print(f"This is a {self.type}")

# Derived class Car (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, type_of_vehicle, model):
        super().__init__(type_of_vehicle)  # Calling the constructor of Vehicle
        self.model = model

    def show_model(self):
        print(f"This car is a {self.model}")

# Further derived class ElectricCar (inherits from Car)
class ElectricCar(Car):
    def __init__(self, type_of_vehicle, model, battery):
        super().__init__(type_of_vehicle, model)  # Calling the constructor of Car
        self.battery = battery

    def show_battery(self):
        print(f"This electric car has a {self.battery} battery")

# Creating objects and testing the multi-level inheritance
vehicle = Vehicle("Vehicle")
vehicle.show_type()

car = Car("Car", "Sedan")
car.show_type()
car.show_model()

electric_car = ElectricCar("Electric Car", "Tesla Model S", "100kWh")
electric_car.show_type()
electric_car.show_model()
electric_car.show_battery()
# Out:
# This is a Vehicle
# This is a Car
# This car is a Sedan
# This is a Electric Car
# This car is a Tesla Model S
# This electric car has a 100kWh battery

# %% [markdown]
# Q 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
 # Base class Bird
class Bird:
    def fly(self):
        print("This bird can fly.")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, they waddle instead.")

# Demonstrating Polymorphism
def make_bird_fly(bird):
    bird.fly()

# Create objects of Sparrow and Penguin
sparrow = Sparrow()
penguin = Penguin()

# Pass objects to make_bird_fly to demonstrate polymorphism
make_bird_fly(sparrow)  # Output: Sparrow flies high in the sky!
make_bird_fly(penguin)  # Output: Penguins can't fly, they waddle instead.
# Out:
# Sparrow flies high in the sky!
# Penguins can't fly, they waddle instead.

# %% [markdown]
# Q 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited {amount}. Current balance: {self.__balance}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew {amount}. Current balance: {self.__balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    # Method to check the balance
    def check_balance(self):
        print(f"Current balance: {self.__balance}")

# Create a BankAccount object
account = BankAccount(1000)  # Initial balance of 1000

# Demonstrating encapsulation
account.deposit(500)   # Deposit money
account.withdraw(200)  # Withdraw money
account.check_balance()  # Check balance

# Trying to access the private attribute directly (will raise an error)
# print(account.__balance)  # Uncommenting this will raise an AttributeError
# Out:
# Deposited 500. Current balance: 1500
# Withdrew 200. Current balance: 1300
# Current balance: 1300

# %% [markdown]
# Q 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
# Base class Instrument
class Instrument:
    def play(self):
        print("Playing the instrument.")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Playing the guitar: Strum strum!")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano: Ding ding!")

# Function to demonstrate polymorphism
def perform_play(instrument):
    instrument.play()

# Creating objects of Guitar and Piano
guitar = Guitar()
piano = Piano()

# Demonstrating runtime polymorphism
perform_play(guitar)  # Output: Playing the guitar: Strum strum!
perform_play(piano)   # Output: Playing the piano: Ding ding!
# Out:
# Playing the guitar: Strum strum!
# Playing the piano: Ding ding!

# %% [markdown]
#  Q 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Using the class method to add numbers
sum_result = MathOperations.add_numbers(10, 5)
print(f"Sum: {sum_result}")

# Using the static method to subtract numbers
difference_result = MathOperations.subtract_numbers(10, 5)
print(f"Difference: {difference_result}")
# Out:
# Sum: 15
# Difference: 5

# %% [markdown]
# Q 8.Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    # Class variable to keep track of the total number of persons created
    total_persons = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        # Increment the total_persons count each time a new person is created
        Person.total_persons += 1

    # Class method to get the total number of persons created
    @classmethod
    def count_persons(cls):
        return cls.total_persons

# Creating instances of Person
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)
person3 = Person("Charlie", 35)

# Calling the class method to count the total number of persons created
print(f"Total persons created: {Person.count_persons()}")
# Out:
# Total persons created: 3

# %% [markdown]
# Q 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Overriding the __str__ method to display the fraction as "numerator/denominator"
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating instances of Fraction
fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 6)

# Printing the fractions
print(fraction1)  # Output: 3/4
print(fraction2)  # Output: 5/6
# Out:
# 3/4
# 5/6

# %% [markdown]
# Q 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overriding the __add__ method to add two vectors
    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise ValueError("Operand must be an instance of Vector")

    # Overriding the __str__ method to display the vector in (x, y) format
    def __str__(self):
        return f"({self.x}, {self.y})"

# Creating instances of Vector
vector1 = Vector(1, 2)
vector2 = Vector(3, 4)

# Adding two vectors using the overloaded + operator
result_vector = vector1 + vector2

# Printing the result of vector addition
print(f"Result of adding vector1 and vector2: {result_vector}")
# Out:
# Result of adding vector1 and vector2: (4, 6)

# %% [markdown]
# Q 11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name  # Attribute for name
        self.age = age    # Attribute for age

    # Method to greet the person
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an instance of Person
person1 = Person("Alice", 30)

# Calling the greet method
person1.greet()  # Output: Hello, my name is Alice and I am 30 years old.
# Out:
# Hello, my name is Alice and I am 30 years old.

# %% [markdown]
# Q 12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name        # Attribute for the student's name
        self.grades = grades    # Attribute for the student's grades (a list of grades)

    # Method to compute the average grade
    def average_grade(self):
        if len(self.grades) > 0:  # Check to avoid division by zero
            return sum(self.grades) / len(self.grades)
        else:
            return 0  # If no grades, return 0

# Creating an instance of Student
student1 = Student("John", [85, 90, 78, 92])

# Calling the average_grade method to calculate the average
print(f"{student1.name}'s average grade: {student1.average_grade()}")
# Out:
# John's average grade: 86.25

# %% [markdown]
# Q 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0   # Initialize length to 0
        self.width = 0    # Initialize width to 0

    # Method to set the dimensions (length and width)
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate the area of the rectangle
    def area(self):
        return self.length * self.width

# Creating an instance of Rectangle
rectangle1 = Rectangle()

# Setting the dimensions of the rectangle
rectangle1.set_dimensions(5, 3)

# Calling the area method to calculate the area
print(f"Area of the rectangle: {rectangle1.area()}")  # Output: 15
# Out:
# Area of the rectangle: 15

# %% [markdown]
# Q 14.Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate salary based on hours worked and hourly rate
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)  # Calling the parent class constructor
        self.bonus = bonus  # Additional attribute for bonus

    # Method to calculate salary including the bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()  # Calculate base salary using parent class method
        return base_salary + self.bonus  # Add the bonus to the base salary


# Creating an instance of Employee
employee1 = Employee("John", 40, 20)  # 40 hours worked at $20 per hour

# Calculating salary for employee1
print(f"{employee1.name}'s salary: ${employee1.calculate_salary()}")

# Creating an instance of Manager (which is derived from Employee)
manager1 = Manager("Alice", 40, 30, 500)  # 40 hours worked at $30 per hour + $500 bonus

# Calculating salary for manager1
print(f"{manager1.name}'s salary: ${manager1.calculate_salary()}")
# Out:
# John's salary: $800
# Alice's salary: $1700

# %% [markdown]
# Q 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

# Example usage:
product1 = Product("Laptop", 50000, 2)

print(f"Product Name: {product1.name}")
print(f"Total Price: {product1.total_price()}")
# Out:
# Product Name: Laptop
# Total Price: 100000

# %% [markdown]
# Q 16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        print("Cow says Moo!")

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa!")

# Example usage
cow = Cow()
cow.sound()  # Output: Cow says Moo!

sheep = Sheep()
sheep.sound()  # Output: Sheep says Baa!
# Out:
# Cow says Moo!
# Sheep says Baa!

# %% [markdown]
# Q 17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's detail

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return formatted book information
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Example usage
book1 = Book("The Alchemist", "Paulo Coelho", 1988)
print(book1.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988

# %% [markdown]
# Q 18.Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
# Parent Class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"Address: {self.address}, Price: {self.price}"

# Derived Class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        # Call parent class constructor using super()
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        return f"Address: {self.address}, Price: {self.price}, Rooms: {self.number_of_rooms}"

# Example usage
mansion1 = Mansion("123 Luxury St", 5000000, 10)
print(mansion1.get_info())
# Out:
# Address: 123 Luxury St, Price: 5000000, Rooms: 10

# %%
####################################################END############################################################
